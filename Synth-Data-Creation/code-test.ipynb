# %%
from DG import *

# %%
df,gr,we,cf = genSynthData()

# %%
df
# Out:
#            f0        f1        f2        f3        f4        f5        f6  \
# 0   -1.875001 -1.803841 -0.207979 -0.612318  0.249337 -0.621231 -0.661710
# 1   -1.306635 -0.313156  1.434609 -2.024274  1.429174  0.542080 -0.813951
# 2   -0.191622 -0.325814 -0.678752 -0.096515  0.844624  0.585228  1.053465
# 3   -1.238807 -1.644363 -2.131455  0.755104  0.054945 -0.190784  0.519929
# 4   -2.856516 -2.512372 -1.125856  0.132390 -1.036243  0.768130  0.588408
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  1.167423  0.914286  0.029958  0.181050 -0.479761 -0.323844  1.008536
# 396 -0.671465 -0.798811 -1.194040  0.781180 -1.694706 -0.731138 -1.197431
# 397  0.433722  0.672755 -0.200679  0.440735 -0.337493 -0.773611 -1.422957
# 398 -0.403663  0.569963  0.341821 -0.329418  0.499903 -1.133354 -0.557170
# 399  0.434043 -1.496382 -2.148347  0.172230  1.932535 -0.627944 -1.310420
#
#            f7        f8        f9       f10          y
# ...

# %%
gr
# Out:
# [5]

# %%
we
# Out:
# [[0.818285283966157,
#   0.8540554519136347,
#   -0.6591931174956939,
#   -0.5072915120959917]]

# %%
#colouring function 
def color_thresh(val,thres=0.5):
    if abs(val)>=thres:
        if val<0:
            return 'background-color: red'
        else:
            return 'background-color: green'
    else:
        return ''

# %%
display(df.iloc[:,:-1].corr().style.applymap(color_thresh))
# Out:
# <style type="text/css">
# #T_49a5e_row0_col0, #T_49a5e_row0_col1, #T_49a5e_row1_col0, #T_49a5e_row1_col1, #T_49a5e_row1_col2, #T_49a5e_row2_col1, #T_49a5e_row2_col2, #T_49a5e_row3_col3, #T_49a5e_row4_col4, #T_49a5e_row5_col5, #T_49a5e_row6_col6, #T_49a5e_row7_col7, #T_49a5e_row8_col8, #T_49a5e_row9_col9, #T_49a5e_row10_col10 {
#   background-color: green;
# }
# #T_49a5e_row2_col3, #T_49a5e_row3_col2, #T_49a5e_row3_col4, #T_49a5e_row4_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_49a5e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >f0</th>
#       <th class="col_heading level0 col1" >f1</th>
#       <th class="col_heading level0 col2" >f2</th>
#       <th class="col_heading level0 col3" >f3</th>
#       <th class="col_heading level0 col4" >f4</th>
#       <th class="col_heading level0 col5" >f5</th>
#       <th class="col_heading level0 col6" >f6</th>
# ...
